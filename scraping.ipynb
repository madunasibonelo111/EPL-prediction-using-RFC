# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   WARNING: The script normalizer.exe is installed in 'C:\Users\sibon\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0
# [notice] To update, run: C:\Users\sibon\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0
# [notice] To update, run: C:\Users\sibon\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# %pip instll requests
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "instll" - maybe you meant "install"

# %%
# %pip install requests
# Out:
# ...
#      ---------------------------------------- 0.0/64.7 kB ? eta -:--:--
#      ------------------ ------------------- 30.7/64.7 kB 435.7 kB/s eta 0:00:01
#      ------------------ ------------------- 30.7/64.7 kB 435.7 kB/s eta 0:00:01
#      ------------------------ ------------- 41.0/64.7 kB 245.8 kB/s eta 0:00:01
#      -------------------------------------- 64.7/64.7 kB 289.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/107.2 kB ? eta -:--:--
#      ----------- ---------------------------- 30.7/107.2 kB ? eta -:--:--
#      -------------------------------------- 107.2/107.2 kB 2.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/71.0 kB ? eta -:--:--
#      ---------------------------------------- 71.0/71.0 kB 1.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/152.9 kB ? eta -:--:--
#      -------- ------------------------------- 30.7/152.9 kB ? eta -:--:--
# ...

# %%
import requests
